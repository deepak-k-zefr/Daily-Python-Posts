# %%
import pandas as pd
from time import sleep
from random import randint
from requests import get
from time import time
from IPython.core.display import clear_output
from bs4 import BeautifulSoup
import re
import hashlib
import json
from warnings import warn
from lxml import html  
import json
import requests
from time import sleep
import re,urllib
import argparse

# %%
import requests
url="https://www.yelp.com/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA"
result = requests.get(url)
soup=BeautifulSoup(result.content)
# Out:
# /Users/deepak/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/deepak/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
result.status_code
# Out:
# 200

# %%
response = requests.get(url).text
parser = html.fromstring(response)
print ("Parsing the page")
# Out:
# Parsing the page

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #header_find_form
# turtfeddfbqseew.html
# #header-nav
# #page-content
# /
# None
# /signup
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3DCoffee%2BShop%26find_loc%3DBoston%252C%2BMA
# javascript:;
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3DCoffee%2BShop%26find_loc%3DBoston%252C%2BMA
# /signup
# /user_details
# /talk
# https://support.google.com/chrome/answer/142065?co=GENIE.Platform%3DDesktop&hl=en&oco=0
# None
# https://support.apple.com/en-us/HT204690
# https://www.mozilla.org/en-US/firefox/geolocation/
# /search?cflt=restaurants
# /search?cflt=nightlife
# /search?cflt=homeservices
# /search?cflt=hvac
# /search?cflt=contractors
# /search?cflt=electricians
# /search?cflt=homecleaning
# /search?cflt=landscaping
# /search?cflt=locksmiths
# /search?cflt=movers
# /search?cflt=painters
# /search?cflt=plumbing
# /writeareview
# /events
# /talk
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3DCoffee%2BShop%26find_loc%3DBoston%252C%2BMA
# javascript:;
# javascript:;
# javascript:;
# /adredir?ad_business_id=9Ih-4eMu4qaOL0E05JrOwA&campaign_id=WDV7tF8ceGULF4mdbQHfrQ&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fkung-fu-tea-brighton&request_id=f32ebe43243003e6&signature=451ab6ecc131345dc895b7543f2a469438a8498b56bc121ba218a87884f5fd13&slot=0
# /adredir?ad_business_id=9Ih-4eMu4qaOL0E05JrOwA&campaign_id=WDV7tF8ceGULF4mdbQHfrQ&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fkung-fu-tea-brighton&request_id=f32ebe43243003e6&signature=451ab6ecc131345dc895b7543f2a469438a8498b56bc121ba218a87884f5fd13&slot=0
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=juicebars&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=bubbletea&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /adredir?ad_business_id=9Ih-4eMu4qaOL0E05JrOwA&campaign_id=WDV7tF8ceGULF4mdbQHfrQ&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fkung-fu-tea-brighton&request_id=f32ebe43243003e6&signature=451ab6ecc131345dc895b7543f2a469438a8498b56bc121ba218a87884f5fd13&slot=0
# /adredir?ad_business_id=9Ih-4eMu4qaOL0E05JrOwA&campaign_id=WDV7tF8ceGULF4mdbQHfrQ&click_origin=read_more&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fkung-fu-tea-brighton&request_id=f32ebe43243003e6&signature=451ab6ecc131345dc895b7543f2a469438a8498b56bc121ba218a87884f5fd13&slot=0
# /biz/thinking-cup-boston-5?osq=Coffee+Shop
# /biz/thinking-cup-boston-5?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=breakfast_brunch&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=sandwiches&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=0UOusbByUisaHvIfuTAr_g
# /biz/thinking-cup-boston-5?hrid=WLe9lVZ8jzAEYfB9rjxVvQ&osq=Coffee+Shop
# /biz/render-coffee-boston?osq=Coffee+Shop
# /biz/render-coffee-boston?osq=Coffee+Shop
# /search?cflt=cafes&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=oghdP2RZlUucmjfWiBXJyQ
# /biz/render-coffee-boston?hrid=R9S75eylGDLVs63t8J8jmg&osq=Coffee+Shop
# /biz/polcaris-coffee-boston?osq=Coffee+Shop
# /biz/polcaris-coffee-boston?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=oXvbWXeh1tlchQmNbkgK7A
# /biz/polcaris-coffee-boston?hrid=1LstunKHg-NgmAfeESmyPA&osq=Coffee+Shop
# /biz/gracenote-boston-4?osq=Coffee+Shop
# /biz/gracenote-boston-4?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=K1KliKzlGGKeWDN9AXxu0Q
# /biz/gracenote-boston-4?hrid=AChj7fCchv1NfL3kKvDstA&osq=Coffee+Shop
# /biz/wired-puppy-boston?osq=Coffee+Shop
# /biz/wired-puppy-boston?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=atiLFMCQsRpdhHGlAPEfNg
# /biz/wired-puppy-boston?hrid=daGvne4vABe309PBeRbtVg&osq=Coffee+Shop
# /biz/barrington-coffee-roasting-company-boston-2?osq=Coffee+Shop
# /biz/barrington-coffee-roasting-company-boston-2?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=lxaBfy6snoCHWtN5KPrZtw
# /biz/barrington-coffee-roasting-company-boston-2?hrid=CKxAGwDpv5Ax98SNeyjb-Q&osq=Coffee+Shop
# /biz/jaho-coffee-roaster-and-wine-bar-boston?osq=Coffee+Shop
# /biz/jaho-coffee-roaster-and-wine-bar-boston?osq=Coffee+Shop
# /search?cflt=wine_bars&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=CvEJxu4gfEeG2FPaJKkD3w
# /biz/jaho-coffee-roaster-and-wine-bar-boston?hrid=2w9Rd8YiCwVWMaVCn4dxkg&osq=Coffee+Shop
# /biz/caff%C3%A8-nero-boston-8?osq=Coffee+Shop
# /biz/caff%C3%A8-nero-boston-8?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=fdoG5_PAZ0KqMP81RqU0vw
# /biz/caff%C3%A8-nero-boston-8?hrid=4XJ1YBGMfomZZYAEiCRmSA&osq=Coffee+Shop
# /biz/ogawa-coffee-boston-2?osq=Coffee+Shop
# /biz/ogawa-coffee-boston-2?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=sandwiches&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /search?cflt=cafes&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=t68Z6eSgjgdMTl5GIQB-_Q
# /biz/ogawa-coffee-boston-2?hrid=seafpmRIwaaZvTBaSBrJmg&osq=Coffee+Shop
# /biz/thinking-cup-boston-2?osq=Coffee+Shop
# /biz/thinking-cup-boston-2?osq=Coffee+Shop
# /search?cflt=coffee&find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# /user_details?userid=hyVf5YCKUCwFkcUc-0QgZg
# /biz/thinking-cup-boston-2?hrid=rHP5qJpcNKBnVnQMsFwtSw&osq=Coffee+Shop
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=10
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=20
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=30
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=40
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=50
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=60
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=70
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=80
# /search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA&start=10
# /search?find_desc=chai+latte&find_loc=Boston%2C+MA
# /search?find_desc=cheap+coffee&find_loc=Boston%2C+MA
# /search?find_desc=coffee+free+wifi&find_loc=Boston%2C+MA
# /search?find_desc=coffee+laptop&find_loc=Boston%2C+MA
# /search?find_desc=coffee+shop+work&find_loc=Boston%2C+MA
# /search?find_desc=coffee+shops+free+wifi+study&find_loc=Boston%2C+MA
# /search?find_desc=cozy+coffee+shop&find_loc=Boston%2C+MA
# /search?find_desc=espresso+coffee&find_loc=Boston%2C+MA
# /search?find_desc=late+night+cafe&find_loc=Boston%2C+MA
# /search?find_desc=late+night+study&find_loc=Boston%2C+MA
# /search?find_desc=local+coffee+shop&find_loc=Boston%2C+MA
# /search?find_desc=peets+cafe&find_loc=Boston%2C+MA
# /search?find_desc=vietnamese+coffee+shop&find_loc=Boston%2C+MA
# javascript:;
# None
# /topic/cambridge-best-coffee-around-not-best-coffee-shop-or-best-coffee-shop-food
# /topic/cambridge-best-coffee-around-not-best-coffee-shop-or-best-coffee-shop-food
# /topic/boston-coffee-shop-to-host-event
# /topic/boston-coffee-shop-to-host-event
# /topic/bedford-coffee-shop-with-board-games
# /topic/bedford-coffee-shop-with-board-games
# /message_board_search
# /list/RG8nuQxeadF9u-1w0kkXgA
# /list/RG8nuQxeadF9u-1w0kkXgA
# /list/UD7c4ypR_N4GWSwfVncQoQ
# /list/UD7c4ypR_N4GWSwfVncQoQ
# /list/u3wDU1MKekxn5KpbkJktiw
# /list/u3wDU1MKekxn5KpbkJktiw
# /list_search?location=Boston%2C+MA&q=Coffee+Shop&sort=relevance
# /search/add_business/search_button_www?search_loc=Boston%2C+MA
# /contact?topic=feedback
# /search/add_business/modal_button_www?search_loc=Boston%2C+MA
# /search/add_business/modal_button_biz
# https://yelp.com/about
# /careers/home
# /press
# http://yelp-ir.com/
# /guidelines
# /static?p=tos
# /tos/privacy_policy
# /static?locale=en_US&p=privacy#third-parties
# /local_yelp
# https://officialblog.yelp.com/
# https://www.yelp-support.com/?l=en_US
# /yelpmobile?source=footer
# /developers?country=US
# /rss
# https://biz.yelp.com/?utm_campaign=claim_business&utm_content=claim_footer_link&utm_medium=www&utm_source=footer
# /advertise
# https://www.yelpreservations.com/
# https://biz.yelp.com/support/case_studies
# https://www.yelp-support.com/Yelp_for_Business_Owners?l=en_US
# https://www.yelpblog.com/section/business
# javascript:;
# https://ms.yelp.my/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.cz/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.dk/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.de/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://de.yelp.ch/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.at/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.au/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://en.yelp.be/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.ca/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://en.yelp.com.hk/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://en.yelp.my/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://nz.yelp.com/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://en.yelp.com.ph/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.ie/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.sg/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://en.yelp.ch/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.co.uk/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.ar/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.cl/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.es/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.mx/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://fil.yelp.com.ph/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://fr.yelp.be/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://fr.yelp.ca/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.fr/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://fr.yelp.ch/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.it/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://it.yelp.ch/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://nl.yelp.be/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.nl/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.no/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.pl/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.br/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.pt/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://fi.yelp.fi/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://sv.yelp.fi/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.se/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.tr/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.co.jp/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://www.yelp.com.tw/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# https://zh.yelp.com.hk/search?find_desc=Coffee+Shop&find_loc=Boston%2C+MA
# javascript:;
# https://www.yelp.com.ar/
# https://www.yelp.com.au/
# https://www.yelp.at/
# https://en.yelp.be/
# https://www.yelp.com.br/
# https://www.yelp.ca/
# https://www.yelp.cl/
# https://www.yelp.cz/
# https://www.yelp.dk/
# https://fi.yelp.fi/
# https://www.yelp.fr/
# https://www.yelp.de/
# https://en.yelp.com.hk/
# https://www.yelp.it/
# https://www.yelp.co.jp/
# https://en.yelp.my/
# https://www.yelp.com.mx/
# https://nz.yelp.com/
# https://www.yelp.no/
# https://en.yelp.com.ph/
# https://www.yelp.pl/
# https://www.yelp.pt/
# https://www.yelp.ie/
# https://www.yelp.com.sg/
# https://www.yelp.es/
# https://www.yelp.se/
# https://en.yelp.ch/
# https://www.yelp.com.tw/
# https://www.yelp.nl/
# https://www.yelp.com.tr/
# https://www.yelp.co.uk/
# https://www.yelp.com/
# /atlanta
# /austin
# /boston
# /chicago
# /dallas
# /denver
# /detroit
# /honolulu
# /houston
# /la
# /miami
# /minneapolis
# /nyc
# /philadelphia
# /portland
# /sacramento
# /san-diego
# /sf
# /san-jose
# /seattle
# /dc
# /locations
# https://yelp.com/about
# https://officialblog.yelp.com/
# https://www.yelp-support.com/?l=en_US
# /static?p=tos
# http://www.databyacxiom.com

# %%
response
# Out:
# 'Forbidden'
