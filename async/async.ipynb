# %%
# https://hackernoon.com/asynchronous-python-45df84b82434

# %%
import asyncio
import time

# %%
def is_prime(x):
    return  not any(x%i==0 for i in range(2,int(x/2)))

# %%
def highest_prime_below(x):
    for i in range(x,1,-1):
        if  is_prime(i):
            print("Highest prime below %d is %d"%(x,i))
            break

# %%
# %%time
highest_prime_below(100)
highest_prime_below(1000)
highest_prime_below(10000)
# Out:
# Highest prime below 100 is 97
# Highest prime below 1000 is 997
# Highest prime below 10000 is 9973
# CPU times: user 1.38 ms, sys: 626 µs, total: 2.01 ms
# Wall time: 1.46 ms

# %%
async def highest_prime_below(x):
      print('Highest prime below %d' % x)
      for y in range(x-1, 0, -1):
         if is_prime(y):
            print('→ Highest prime below %d is %d' % (x, y))
            return y
         await asyncio.sleep(0.0001)   #  sleep so that other functions can be utilized
      return None

# %%
# %%time
async def main():
    await asyncio.wait( [
        highest_prime_below(100000),
        highest_prime_below(10000),
        highest_prime_below(1000)
        ] )
    
    
loop = asyncio.get_event_loop()
loop.run_until_complete(main())
#loop.close()
# Out:
# Highest prime below 100000
# Highest prime below 1000
# Highest prime below 10000
# → Highest prime below 1000 is 997
# → Highest prime below 100000 is 99991
# → Highest prime below 10000 is 9973
# CPU times: user 10.7 ms, sys: 2.29 ms, total: 13 ms
# Wall time: 13.4 ms

# %%
import tornado.ioloop
from tornado.httpclient import AsyncHTTPClient
urls = ['http://www.google.com', 'http://www.yandex.ru', 'http://www.python.org']

def handle_response(response):
    if response.error:
        print("Error:", response.error)
    else:
        url = response.request.url
        data = response.body
        print('{}: {} bytes: {}'.format(url, len(data), data))

http_client = AsyncHTTPClient()
for url in urls:
    http_client.fetch(url, handle_response)
    
tornado.ioloop.IOLoop.instance().start()
# Out:
# http://www.google.com: 47873 bytes: b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2018/doodle-snow-games-day-14-6465015337975808-l.png" itemprop="image"><meta content="Day 13 of the Doodle Snow Games!" property="twitter:title"><meta content="Day 13 of the Doodle Snow Games! &#10052; #GoogleDoodle" property="twitter:description"><meta content="Day 13 of the Doodle Snow Games! &#10052; #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2018/doodle-snow-games-day-14-
# ...
